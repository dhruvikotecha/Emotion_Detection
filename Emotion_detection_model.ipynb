# %% [markdown]
# ## Emotion Detection

# %%
import matplotlib.pyplot as plt
from glob import glob
import cv2
import random
import os
# %matplotlib inline

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Input, Dropout, Flatten, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation, MaxPooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model

from IPython.display import SVG,Image
import tensorflow as tf
print('Tensorflow Version :',tf.__version__)
# Out:
# WARNING:tensorflow:From f:\Emotion_Detection\emotion_detection_app\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Tensorflow Version : 2.15.0

# %% [markdown]
# ## Exploring Dataset

# %%
images = glob('train/**/**')
for i in range(9):
    image = random.choice(images)
    plt.figure(figsize=(12,12))
    plt.subplot(331+i)
    plt.imshow(cv2.imread(image))
    plt.axis('off')

# %% [markdown]
# ## Preparing Data for Training

# %%
img_size = 48
batch_size = 64
datagen_train = ImageDataGenerator()
train_generator = datagen_train.flow_from_directory('train/',
                                                    target_size = (img_size,img_size),
                                                    color_mode = 'grayscale',
                                                    batch_size = batch_size,
                                                    class_mode = 'categorical',
                                                    shuffle = True)

datagen_validation = ImageDataGenerator()
validation_generator = datagen_validation.flow_from_directory('test/',
                                                    target_size = (img_size,img_size),
                                                    color_mode = 'grayscale',
                                                    batch_size = batch_size,
                                                    class_mode = 'categorical',
                                                    shuffle = True)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# ## Defining Model

# %%
def Convolution(input_tensor, filters, kernel_size):
    x = Conv2D(filters=filters, kernel_size=kernel_size, padding='same')(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2,2))(x)
    x = Dropout(0.25)(x)

    return x

# %%
def Dense_f(input_tensor, nodes):
    x = Dense(nodes)(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.25)(x)

    return x

# %%
def model_fer(input_shape):
    inputs = Input(input_shape)
    conv_1 = Convolution(inputs, 32, (3,3))
    conv_2 = Convolution(inputs, 64, (5,5))
    conv_3 = Convolution(inputs, 128, (3,3))

    flatten = Flatten()(conv_3)

    dense_1 = Dense_f(flatten,256)

    output = Dense(7, activation='softmax')(dense_1)

    model = Model(inputs=[inputs], outputs=[output])
    model.compile(loss=['categorical_crossentropy'], optimizer='adam', metrics='accuracy')

    return model

# %%
model = model_fer((48,48,1))
model.summary()
# Out:
# WARNING:tensorflow:From f:\Emotion_Detection\emotion_detection_app\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From f:\Emotion_Detection\emotion_detection_app\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From f:\Emotion_Detection\emotion_detection_app\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 1)]       0
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 128)       1280
#
#  batch_normalization_2 (Bat  (None, 48, 48, 128)       512
#  chNormalization)
#
#  activation_2 (Activation)   (None, 48, 48, 128)       0
#
#  max_pooling2d_2 (MaxPoolin  (None, 24, 24, 128)       0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 24, 24, 128)       0
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 256)               18874624
#
#  batch_normalization_3 (Bat  (None, 256)               1024
#  chNormalization)
#
#  activation_3 (Activation)   (None, 256)               0
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 18879239 (72.02 MB)
# Trainable params: 18878471 (72.02 MB)
# Non-trainable params: 768 (3.00 KB)
# _________________________________________________________________

# %%
epochs = 15
steps_per_epoch = train_generator.n//train_generator.batch_size
validation_steps = validation_generator.n//validation_generator.batch_size

checkpoint = ModelCheckpoint('model_weights.h5', 
                             monitor='val_accuracy', 
                             save_weights_only=True, 
                             mode='max', 
                             verbose=1)
callbacks = [checkpoint]

# %% [markdown]
# ## Training the Model

# %%
history = model.fit(
    x = train_generator,
    steps_per_epoch = steps_per_epoch,
    epochs = epochs,
    validation_data = validation_generator,
    validation_steps = validation_steps,
    callbacks = callbacks)
# Out:
# Epoch 1/15
# WARNING:tensorflow:From f:\Emotion_Detection\emotion_detection_app\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From f:\Emotion_Detection\emotion_detection_app\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 448/448 [==============================] - ETA: 0s - loss: 1.6431 - accuracy: 0.3813
# Epoch 1: saving model to model_weights.h5
# 448/448 [==============================] - 1180s 3s/step - loss: 1.6431 - accuracy: 0.3813 - val_loss: 1.5432 - val_accuracy: 0.4078
# Epoch 2/15
# 448/448 [==============================] - ETA: 0s - loss: 1.3458 - accuracy: 0.4886
# Epoch 2: saving model to model_weights.h5
# 448/448 [==============================] - 187s 418ms/step - loss: 1.3458 - accuracy: 0.4886 - val_loss: 1.4625 - val_accuracy: 0.4318
# Epoch 3/15
# 448/448 [==============================] - ETA: 0s - loss: 1.1883 - accuracy: 0.5528
# Epoch 3: saving model to model_weights.h5
# 448/448 [==============================] - 187s 418ms/step - loss: 1.1883 - accuracy: 0.5528 - val_loss: 2.0136 - val_accuracy: 0.2782
# Epoch 4/15
# 448/448 [==============================] - ETA: 0s - loss: 1.0573 - accuracy: 0.6108
# Epoch 4: saving model to model_weights.h5
# 448/448 [==============================] - 187s 417ms/step - loss: 1.0573 - accuracy: 0.6108 - val_loss: 1.4570 - val_accuracy: 0.4664
# Epoch 5/15
# 448/448 [==============================] - ETA: 0s - loss: 0.9311 - accuracy: 0.6601
# Epoch 5: saving model to model_weights.h5
# 448/448 [==============================] - 184s 409ms/step - loss: 0.9311 - accuracy: 0.6601 - val_loss: 1.6468 - val_accuracy: 0.4337
# Epoch 6/15
# 448/448 [==============================] - ETA: 0s - loss: 0.8080 - accuracy: 0.7086
# Epoch 6: saving model to model_weights.h5
# 448/448 [==============================] - 184s 411ms/step - loss: 0.8080 - accuracy: 0.7086 - val_loss: 1.6525 - val_accuracy: 0.4014
# Epoch 7/15
# 448/448 [==============================] - ETA: 0s - loss: 0.6946 - accuracy: 0.7542
# Epoch 7: saving model to model_weights.h5
# 448/448 [==============================] - 184s 411ms/step - loss: 0.6946 - accuracy: 0.7542 - val_loss: 1.7936 - val_accuracy: 0.4478
# Epoch 8/15
# 448/448 [==============================] - ETA: 0s - loss: 0.5992 - accuracy: 0.7890
# Epoch 8: saving model to model_weights.h5
# 448/448 [==============================] - 186s 415ms/step - loss: 0.5992 - accuracy: 0.7890 - val_loss: 1.5344 - val_accuracy: 0.4855
# Epoch 9/15
# 448/448 [==============================] - ETA: 0s - loss: 0.5080 - accuracy: 0.8253
# Epoch 9: saving model to model_weights.h5
# 448/448 [==============================] - 187s 418ms/step - loss: 0.5080 - accuracy: 0.8253 - val_loss: 1.7113 - val_accuracy: 0.4854
# Epoch 10/15
# 448/448 [==============================] - ETA: 0s - loss: 0.4418 - accuracy: 0.8482
# Epoch 10: saving model to model_weights.h5
# 448/448 [==============================] - 184s 409ms/step - loss: 0.4418 - accuracy: 0.8482 - val_loss: 2.3400 - val_accuracy: 0.3793
# Epoch 11/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3907 - accuracy: 0.8684
# Epoch 11: saving model to model_weights.h5
# 448/448 [==============================] - 187s 417ms/step - loss: 0.3907 - accuracy: 0.8684 - val_loss: 1.7771 - val_accuracy: 0.4791
# Epoch 12/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3369 - accuracy: 0.8867
# Epoch 12: saving model to model_weights.h5
# 448/448 [==============================] - 187s 418ms/step - loss: 0.3369 - accuracy: 0.8867 - val_loss: 1.8413 - val_accuracy: 0.4940
# Epoch 13/15
# 448/448 [==============================] - ETA: 0s - loss: 0.2916 - accuracy: 0.9036
# Epoch 13: saving model to model_weights.h5
# 448/448 [==============================] - 215s 480ms/step - loss: 0.2916 - accuracy: 0.9036 - val_loss: 1.9231 - val_accuracy: 0.4725
# Epoch 14/15
# 448/448 [==============================] - ETA: 0s - loss: 0.2654 - accuracy: 0.9130
# Epoch 14: saving model to model_weights.h5
# 448/448 [==============================] - 189s 422ms/step - loss: 0.2654 - accuracy: 0.9130 - val_loss: 2.0262 - val_accuracy: 0.4806
# Epoch 15/15
# 448/448 [==============================] - ETA: 0s - loss: 0.2441 - accuracy: 0.9203
# Epoch 15: saving model to model_weights.h5
# 448/448 [==============================] - 192s 429ms/step - loss: 0.2441 - accuracy: 0.9203 - val_loss: 2.0439 - val_accuracy: 0.4823

# %%
model.evaluate(validation_generator)
# Out:
# 113/113 [==============================] - 10s 84ms/step - loss: 2.0441 - accuracy: 0.4823
# [2.0440597534179688, 0.4823070466518402]

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.legend(['Train','Validation'], loc='upper left')
plt.subplots_adjust(top=1.0, bottom=0.0, right=0.95, left=0.0, hspace=0.25, wspace=0.3)

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.legend(['Train','Validation'], loc='upper left')
plt.subplots_adjust(top=1.0, bottom=0.0, right=0.95, left=0.0, hspace=0.25, wspace=0.3)

# %% [markdown]
# ## Saving Model

# %%
model_json = model.to_json()
with open('model_a.json','w') as json_file:
    json_file.write(model_json)
